# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_19196\2353726770.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
train1 = pd.read_csv('job_skills.csv')

# %%
train1.head(20)
# Out:
#                                              job_link  \
# 0   https://www.linkedin.com/jobs/view/housekeeper...
# 1   https://www.linkedin.com/jobs/view/assistant-g...
# 2   https://www.linkedin.com/jobs/view/school-base...
# 3   https://www.linkedin.com/jobs/view/electrical-...
# 4   https://www.linkedin.com/jobs/view/electrical-...
# 5   https://www.linkedin.com/jobs/view/senior-lead...
# 6   https://www.linkedin.com/jobs/view/program-con...
# 7   https://www.linkedin.com/jobs/view/veterinary-...
# 8   https://www.linkedin.com/jobs/view/sr-technici...
# 9   https://www.linkedin.com/jobs/view/experienced...
# 10  https://www.linkedin.com/jobs/view/host-hostes...
# 11  https://www.linkedin.com/jobs/view/maintenance...
# 12  https://www.linkedin.com/jobs/view/traveling-f...
# 13  https://www.linkedin.com/jobs/view/travel-alli...
# 14  https://ca.linkedin.com/jobs/view/performance-...
# 15  https://www.linkedin.com/jobs/view/analyst-cap...
# ...

# %%
d = {}
for i in range(len(train1["job_skills"])):
    for t in str(train1["job_skills"][i]).split(', '):
        d[t.lower()]=d.get(t.lower(),0)+1
print(len(d))
# Out:
# 2773204

# %%
d = {k: d[k] for k in sorted(d, key=d.get, reverse=True)}

# %%
for x in list(d)[0:20]:
    print (x, d[x])
# Out:
# communication 370143
# customer service 278102
# teamwork 227609
# communication skills 195949
# leadership 185187
# problem solving 149032
# time management 142911
# attention to detail 133975
# problemsolving 129329
# project management 121563
# interpersonal skills 100267
# patient care 99926
# sales 93031
# nursing 88015
# collaboration 87116
# training 83656
# data analysis 81964
# microsoft office suite 75531
# organizational skills 75274
# inventory management 71911

# %%
train2 = pd.read_csv('job_summary.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train2 = pd.read_csv('job_summary.csv')
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
# ...

# %%
train2["job_summary"][0]

# %%
train3 = pd.read_csv('linkedin_job_postings.csv')

# %%
train3.head(20)
# Out:
#                                              job_link  \
# 0   https://www.linkedin.com/jobs/view/account-exe...
# 1   https://www.linkedin.com/jobs/view/registered-...
# 2   https://www.linkedin.com/jobs/view/restaurant-...
# 3   https://www.linkedin.com/jobs/view/independent...
# 4   https://www.linkedin.com/jobs/view/group-unit-...
# 5   https://www.linkedin.com/jobs/view/counselor-0...
# 6   https://www.linkedin.com/jobs/view/registered-...
# 7   https://www.linkedin.com/jobs/view/part-time-h...
# 8   https://uk.linkedin.com/jobs/view/store-manage...
# 9   https://ca.linkedin.com/jobs/view/engineering-...
# 10  https://www.linkedin.com/jobs/view/special-age...
# 11  https://www.linkedin.com/jobs/view/manager-sit...
# 12  https://www.linkedin.com/jobs/view/assistant-v...
# 13  https://www.linkedin.com/jobs/view/control-sys...
# 14  https://www.linkedin.com/jobs/view/lead-sales-...
# 15  https://www.linkedin.com/jobs/view/entry-level...
# ...

# %%
train = pd.merge(train1, train3, on='job_link', how='outer')
train

# %%
t = train3.copy()

# %%
t = t.drop(['job_link',	'last_processed_time',	'got_summary',	'got_ner',	'is_being_worked',	'job_title',	'company',	'job_location',	'first_seen','search_city', 'search_position', 'job_type'], axis=1)

# %%
t['count'] =t.groupby(['search_country', 'job_level'])['job_level']. transform('count')

# %%
 t.groupby(['search_country', 'job_level']).count().head(60)
# Out:
#                              count
# search_country job_level
# Australia      Associate      2892
#                Mid senior    26827
# Canada         Associate      6586
#                Mid senior    49386
# United Kingdom Associate      9651
#                Mid senior   103770
# United States  Associate    124880
#                Mid senior  1024462

# %%
t = train3.copy()
t = t.drop(['job_link',	'job_level', 'is_being_worked' ,'last_processed_time',	'got_summary',	'got_ner',	'job_title',	'company',	'job_location',	'search_city','first_seen',	'search_country', 'search_position', 'job_type'], axis=1)
t['count'] =t.groupby(['job_level', 'is_being_worked' ])['is_being_worked']. transform('count')
t.groupby(['job_level', 'is_being_worked']).count().head(60)
# Out:
#                               count
# job_level  is_being_worked
# Associate  f                 143711
#            t                    298
# Mid senior f                1203267
#            t                   1178

# %%
t = train3.copy()
t = t.drop(['job_link',	'last_processed_time',	'is_being_worked', 'got_summary','job_level','got_ner',	'job_title',	'company',	'job_location',	'search_city','first_seen',	 'job_type'], axis=1)
t = t[t['search_country'] == 'United States']
k = t.groupby('search_position').count().sort_values('search_country', ascending=False)[:10]
k
arr = []
for i in k.index:
    arr.append(i)
k['search_position'] = arr

plt.figure(figsize=(12, 8))
bars = plt.barh(k['search_position'], k['search_country'], color=sns.color_palette("Spectral"))
plt.xlabel('Frequency')
plt.ylabel('Skills')
plt.title('Top 10 Required Skills in LinkedIn', color='red')

# Display both horizontal and vertical grid lines
plt.grid(axis='both', linestyle='-', alpha=0.5)


plt.show()

# %%
t = train3.copy()
t = t.drop(['job_link',	'last_processed_time',	'is_being_worked', 'got_summary','job_level','got_ner',	'job_title',	'company',	'job_location',	'search_city','first_seen',	 'job_type'], axis=1)
t = t[t['search_country'] == 'Australia']
k = t.groupby('search_position').count().sort_values('search_country', ascending=False)[:10]
k
arr = []
for i in k.index:
    arr.append(i)
k['search_position'] = arr

plt.figure(figsize=(12, 8))
bars = plt.barh(k['search_position'], k['search_country'], color=sns.color_palette("Spectral"))
plt.xlabel('Frequency')
plt.ylabel('Skills')
plt.title('Top 10 Required Skills in LinkedIn', color='red')

# Display both horizontal and vertical grid lines
plt.grid(axis='both', linestyle='-', alpha=0.5)


plt.show()

# %%
t = train3.copy()
t = t.drop(['job_link',	'last_processed_time',	'is_being_worked', 'got_summary','job_level','got_ner',	'job_title',	'company',	'job_location',	'search_city','first_seen',	 'job_type'], axis=1)
t = t[t['search_country'] == 'United Kingdom']
k = t.groupby('search_position').count().sort_values('search_country', ascending=False)[:10]
k
arr = []
for i in k.index:
    arr.append(i)
k['search_position'] = arr

plt.figure(figsize=(12, 8))
bars = plt.barh(k['search_position'], k['search_country'], color=sns.color_palette("Spectral"))
plt.xlabel('Frequency')
plt.ylabel('Skills')
plt.title('Top 10 Required Skills in LinkedIn', color='red')

# Display both horizontal and vertical grid lines
plt.grid(axis='both', linestyle='-', alpha=0.5)


plt.show()

# %%
t = train3.copy()
t = t.drop(['job_link',	'last_processed_time',	'is_being_worked', 'got_summary','job_level','got_ner',	'job_title',	'company',	'job_location',	'search_city','first_seen',	 'job_type'], axis=1)
t = t[t['search_country'] == 'Canada']
k = t.groupby('search_position').count().sort_values('search_country', ascending=False)[:10]
k
# Out:
#                                 search_country
# search_position
# Account Executive                          924
# Christian Science Nurse                    753
# Chef                                       689
# Accountant                                 558
# Change Person                              552
# Driver                                     540
# Agricultural-Research Engineer             528
# Consultant Education                       524
# Guide                                      507
# Car Inspector                              474

# %%
arr = []
for i in k.index:
    arr.append(i)
k['search_position'] = arr

# %%
plt.figure(figsize=(12, 8))
bars = plt.barh(k['search_position'], k['search_country'], color=sns.color_palette("Spectral"))
plt.xlabel('Frequency')
plt.ylabel('Skills')
plt.title('Top 10 Required Skills in LinkedIn', color='red')

# Display both horizontal and vertical grid lines
plt.grid(axis='both', linestyle='-', alpha=0.5)


plt.show()

# %%
t = train3.copy()
t = t.drop(['job_link',	'last_processed_time', 'search_position', 'is_being_worked', 'got_summary','job_level','got_ner',	'company',	'job_location',	'search_city','first_seen',	 'job_type'], axis=1)
k = t.groupby('job_title').count().sort_values('search_country', ascending=False)
k
# Out:
#                                                     search_country
# job_title
# LEAD SALES ASSOCIATE-FT                                       7325
# Shift Manager                                                 5818
# First Year Tax Professional                                   5356
# Assistant Manager                                             5346
# Customer Service Representative                               5203
# ...                                                            ...
# Incentives Marketing Manager                                     1
# Incentive Specialist (Customer Onboarding Speci...               1
# Incentive Plan Administrator - Commercial Banking                1
# Incentive Event Supervisor                                       1
# Nurse Practitioner (676525)                                      1
#
# [584544 rows x 1 columns]

# %%
t = train3.copy()
grouped = t.groupby('company').count().head(60)
grouped.sort_values('job_link', ascending=False)
# Out:
#                                                     job_link  \
# company
# #twiceasnice Recruiting                                  179
# 1 Resource Group Staffing                                 50
# 1-800-FLOWERS.COM, INC.                                   39
# 10x Genomics                                              22
# 1199SEIU Benefit and Pension Funds                        22
# .                                                         21
# 1-800Accountant                                           20
# 100x Imaging Inc.                                         15
# (GWI) GOODWILL INTERNATIONAL                              12
# 11Residential                                             10
# 10bits                                                     9
# 1000heads                                                  9
# 10 Percent Recruiting Ltd.                                 9
# 'Alohilani Resort Waikiki Beach                            9
# ...

# %%
t = train3.copy()
grouped = t.groupby('company').count().head(60)
grouped.sort_values('job_link', ascending=False)

# %%
t = train3.copy()

# %%
t = t.drop(['job_link',	'last_processed_time',	'got_summary',	'got_ner',	'job_title',	'company',	'job_location',	'search_city','first_seen',	'search_country', 'search_position', 'job_level'], axis=1)
t['count'] =t.groupby(['job_type', 'is_being_worked'])['is_being_worked']. transform('count')

# %%
t.groupby(['job_type', 'is_being_worked']).count().head(60)
# Out:
#                             count
# job_type is_being_worked
# Hybrid   f                   6560
#          t                      2
# Onsite   f                1336160
#          t                   1473
# Remote   f                   4258
#          t                      1

# %%
traint_australia = train.copy()
traint_australia.drop(traint_australia.loc[traint_australia['search_country']!='Australia'].index, inplace=True)
traint_australia
# Out:
#                                                   job_link  \
# 1        https://ae.linkedin.com/jobs/view/bar-supervis...
# 8        https://ae.linkedin.com/jobs/view/housing-atte...
# 20       https://ae.linkedin.com/jobs/view/waiter-waitr...
# 21       https://ae.linkedin.com/jobs/view/waiter-waitr...
# 22       https://ae.linkedin.com/jobs/view/waiter-waitr...
# ...                                                    ...
# 1236349  https://www.linkedin.com/jobs/view/swell-serve...
# 1250311  https://www.linkedin.com/jobs/view/technical-s...
# 1315312  https://www.linkedin.com/jobs/view/veterinaria...
# 1315348  https://www.linkedin.com/jobs/view/veterinaria...
# 1347295  https://www.linkedin.com/jobs/view/yard-techni...
#
#                                                 job_skills  \
# 1        Bar Supervision, Team Leadership, Beverage Sal...
# 8        Cleaning, Equipment Maintenance, Knowledge of ...
# 20       Waiter/Waitress, Customer service, Food and be...
# ...

# %% [markdown]
# Австралия навыки

# %%
d = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_country"][i] == 'Australia':
            d[t.lower()]=d.get(t.lower(),0)+1

d = {k: d[k] for k in sorted(d, key=d.get, reverse=True)}

for x in list(d)[0:20]:
    print (x, d[x])
# Out:
# communication 7830
# communication skills 5172
# leadership 4840
# teamwork 4822
# customer service 4682
# project management 3580
# time management 3521
# attention to detail 3518
# problem solving 3197
# interpersonal skills 2673
# problemsolving 2528
# collaboration 2440
# sales 1798
# data analysis 1724
# ahpra registration 1699
# adaptability 1634
# organizational skills 1585
# analytical skills 1582
# microsoft office suite 1537
# flexibility 1415

# %%
f = {'skills' : [], 'count' : []}
for x in list(d)[0:20]:
    f['skills'].append(x)
    f['count'].append(d[x])
f
# Out:
# {'skills': ['communication',
#   'communication skills',
#   'leadership',
#   'teamwork',
#   'customer service',
#   'project management',
#   'time management',
#   'attention to detail',
#   'problem solving',
#   'interpersonal skills',
#   'problemsolving',
#   'collaboration',
#   'sales',
#   'data analysis',
#   'ahpra registration',
#   'adaptability',
#   'organizational skills',
#   'analytical skills',
#   'microsoft office suite',
#   'flexibility'],
#  'count': [7830,
#   5172,
#   4840,
#   4822,
#   4682,
#   3580,
#   3521,
#   3518,
#   3197,
#   2673,
#   2528,
#   2440,
#   1798,
#   1724,
#   1699,
#   1634,
#   1585,
#   1582,
#   1537,
#   1415]}

# %%
plt.title("Количество",fontsize=15)
plt.plot(df['count'], df['skills'])
plt.show()

# %%
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Австралия')
plt.legend()
plt.show()

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_country"][i] == 'Canada':
            d1[t.lower()]=d1.get(t.lower(),0)+1

d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['communication',
#   'customer service',
#   'teamwork',
#   'leadership',
#   'communication skills',
#   'problem solving',
#   'time management',
#   'project management',
#   'attention to detail',
#   'problemsolving',
#   'interpersonal skills',
#   'organizational skills',
#   'collaboration',
#   'sales',
#   'data analysis',
#   'microsoft office suite',
#   'analytical skills',
#   'adaptability',
#   'microsoft office',
#   'training'],
#  'count': [17475,
#   11178,
#   11056,
#   10214,
#   9239,
#   8454,
#   7432,
#   7258,
#   6614,
#   6522,
#   5868,
#   4609,
#   4535,
#   4218,
#   3935,
#   3889,
#   3868,
#   3560,
#   3125,
#   3101]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Канада')
plt.legend()
plt.show()

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_country"][i] == 'United Kingdom':
            d1[t.lower()]=d1.get(t.lower(),0)+1

d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['communication',
#   'communication skills',
#   'teamwork',
#   'customer service',
#   'leadership',
#   'attention to detail',
#   'time management',
#   'project management',
#   'problem solving',
#   'problemsolving',
#   'sales',
#   'data analysis',
#   'interpersonal skills',
#   'collaboration',
#   'flexibility',
#   'adaptability',
#   'team management',
#   'microsoft office suite',
#   'training',
#   'analytical skills'],
#  'count': [30899,
#   17967,
#   17665,
#   16954,
#   14591,
#   13815,
#   13062,
#   12896,
#   11956,
#   9354,
#   7791,
#   7201,
#   6712,
#   6584,
#   6398,
#   6370,
#   6043,
#   5922,
#   5824,
#   5375]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Великобритания')
plt.legend()
plt.show()

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_country"][i] == 'United States':
            d1[t.lower()]=d1.get(t.lower(),0)+1

# %%
d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['communication',
#   'customer service',
#   'teamwork',
#   'communication skills',
#   'leadership',
#   'problem solving',
#   'time management',
#   'problemsolving',
#   'attention to detail',
#   'project management',
#   'patient care',
#   'interpersonal skills',
#   'nursing',
#   'sales',
#   'collaboration',
#   'training',
#   'data analysis',
#   'inventory management',
#   'high school diploma',
#   'microsoft office suite'],
#  'count': [313939,
#   245288,
#   194066,
#   163571,
#   155542,
#   125425,
#   118896,
#   110925,
#   110028,
#   97829,
#   92849,
#   85014,
#   80761,
#   79224,
#   73557,
#   73332,
#   69104,
#   66636,
#   65648,
#   64183]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('США')
plt.legend()
plt.show()

# %%
grouped = train.groupby('company').count().head(60)

# %%
grouped.sort_values('job_link', ascending=False)
# Out:
#                                                     job_link  job_skills  \
# company
# #twiceasnice Recruiting                                  179         171
# 1 Resource Group Staffing                                 50          48
# 1-800-FLOWERS.COM, INC.                                   39          38
# 10x Genomics                                              22          20
# 1199SEIU Benefit and Pension Funds                        22          20
# .                                                         21          21
# 1-800Accountant                                           20          20
# 100x Imaging Inc.                                         15          13
# (GWI) GOODWILL INTERNATIONAL                              12          12
# 11Residential                                             10          10
# 10bits                                                     9           9
# 1000heads                                                  9           8
# ...

# %%
grouped = train.groupby('job_location').count().head(60)

# %%
grouped.sort_values('job_link', ascending=False)
# Out:
#                                             job_link  job_skills  \
# job_location
# Aberdeen, Scotland, United Kingdom               777         750
# Aberdeen Proving Ground, MD                      330         312
# Abbotsford, British Columbia, Canada             281         272
# Aberdeen, MD                                     269         254
# Abingdon, England, United Kingdom                171         164
# Abbots Salford, England, United Kingdom          137         129
# Abilene, TX                                      137         121
# Aberdeen, SD                                     130         127
# Abingdon, MD                                      52          50
# Abbott, TX                                        49          49
# Abington, PA                                      39          36
# Abingdon, VA                                      37          34
# Aberdeenshire, Scotland, United Kingdom           36          34
# ...

# %%
grouped = train.groupby('search_position').count().head(60)
grouped.sort_values('job_link', ascending=False)
# Out:
#                                      job_link  job_skills  \
# search_position
# Account Executive                       19468       19463
# Accountant                               9571        9562
# Agricultural-Research Engineer           9549        9542
# Assembler                                8738        8712
# Anesthesiologist                         8229        8218
# Architect                                8041        8029
# Aeronautical-Design Engineer             7199        7191
# Art Therapist                            5934        5908
# Art Director                             4257        4250
# Abstractor                               4037        4030
# Accountant Cost                          3765        3761
# Administrative Assistant                 3628        3625
# Air-Conditioning Mechanic                3002        3001
# Accounting Clerk                         2949        2948
# Administrative Clerk                     2828        2822
# ...

# %%
grouped = train.groupby(['search_country', 'search_city']).count().head(60)
grouped.sort_values('job_link', ascending=False)
# Out:
#                                              job_link  job_skills  \
# search_country search_city
# Australia      New South Wales                   4381        4299
#                Redcliffe                         4296        3891
#                Victoria                          4128        4056
#                Perth                             2478        2444
# Canada         Alberta                           2352        2318
# Australia      Deception Bay                     2123        2105
# Canada         Burlington                        1980        1964
#                Calgary                           1955        1909
# Australia      Sydney                            1545        1527
#                Parramatta                        1418        1212
# Canada         Brantford                         1168        1150
#                Bonavista                         1036         938
# Australia      Western Australia                 1031         962
# ...

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["company"][i] in ['#twiceasnice Recruiting', '1 Resource Group Staffing', '1-800-FLOWERS.COM, INC.']:
            d1[t.lower()]=d1.get(t.lower(),0)+1

d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['communication',
#   'project management',
#   'customer service',
#   'microsoft office',
#   'microsoft office suite',
#   'communication skills',
#   'sales',
#   'troubleshooting',
#   'data analysis',
#   'problem solving',
#   'problemsolving',
#   'teamwork',
#   'attention to detail',
#   "bachelor's degree",
#   "driver's license",
#   'travel',
#   'account management',
#   'time management',
#   'quality control',
#   'collaboration'],
#  'count': [71,
#   47,
#   43,
#   37,
#   37,
#   34,
#   33,
#   33,
#   30,
#   29,
#   29,
#   29,
#   28,
#   25,
#   22,
#   21,
#   21,
#   21,
#   21,
#   20]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Навыки необходимые для топ 3 компаний')
plt.legend()
plt.show()

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_position"][i] == 'Account Executive':
            d1[t.lower()]=d1.get(t.lower(),0)+1

d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['sales',
#   'communication',
#   'account management',
#   'customer service',
#   'business development',
#   'negotiation',
#   'time management',
#   'communication skills',
#   'problem solving',
#   "bachelor's degree",
#   'teamwork',
#   'presentation skills',
#   'microsoft office suite',
#   'relationship building',
#   'prospecting',
#   'data analysis',
#   'leadership',
#   'customer relationship management',
#   'salesforce',
#   'project management'],
#  'count': [9743,
#   7460,
#   6756,
#   4369,
#   4301,
#   4163,
#   4130,
#   3786,
#   3704,
#   3416,
#   3391,
#   3028,
#   3026,
#   3015,
#   2696,
#   2476,
#   2332,
#   2256,
#   2202,
#   2176]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Навыки необходимые для работы Account Executive')
plt.legend()
plt.show()

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_position"][i] == 'Accountant':
            d1[t.lower()]=d1.get(t.lower(),0)+1

d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['accounting',
#   'financial reporting',
#   'attention to detail',
#   'communication',
#   'budgeting',
#   'teamwork',
#   'communication skills',
#   'excel',
#   'financial analysis',
#   'analytical skills',
#   'finance',
#   'financial statements',
#   'time management',
#   'journal entries',
#   'gaap',
#   'accounts payable',
#   'microsoft office suite',
#   'general ledger',
#   'forecasting',
#   'microsoft excel'],
#  'count': [5382,
#   3001,
#   2310,
#   2270,
#   2086,
#   1879,
#   1871,
#   1801,
#   1799,
#   1669,
#   1326,
#   1315,
#   1286,
#   1265,
#   1206,
#   1185,
#   1154,
#   1153,
#   1153,
#   1140]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Навыки необходимые для работы Account Executive')
plt.legend()
plt.show()

# %%
d1 = {}
for i in range(len(train["job_skills"])):
    for t in str(train["job_skills"][i]).split(', '):
        if train["search_position"][i] == 'Anesthesiologist':
            d1[t.lower()]=d1.get(t.lower(),0)+1

d1 = {k: d1[k] for k in sorted(d1, key=d1.get, reverse=True)}

f1 = {'skills' : [], 'count' : []}
for x in list(d1)[0:20]:
    f1['skills'].append(x)
    f1['count'].append(d1[x])
f1
# Out:
# {'skills': ['nursing',
#   'patient care',
#   'communication',
#   'acls',
#   'registered nurse',
#   'bls',
#   'teamwork',
#   'anesthesiology',
#   'critical thinking',
#   'critical care',
#   'leadership',
#   'bls certification',
#   'anesthesia',
#   'collaboration',
#   'patient education',
#   'pals',
#   'acls certification',
#   'documentation',
#   'healthcare',
#   'research'],
#  'count': [2678,
#   2516,
#   1629,
#   1487,
#   1412,
#   1290,
#   1201,
#   1129,
#   1013,
#   1007,
#   805,
#   728,
#   721,
#   683,
#   656,
#   634,
#   593,
#   589,
#   575,
#   558]}

# %%
df = pd.DataFrame(f1)
plt.barh(df['skills'], df['count'],  label='Востребованность навыка') #Параметр label позволяет задать название величины для легенды
plt.xlabel('Количество')
plt.ylabel('Название')
plt.title('Навыки необходимые для работы Account Executive')
plt.legend()
plt.show()
